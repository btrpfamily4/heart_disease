# %% [markdown]
# # 1.IMPORT THE LIBRARIES AND THE DATASETS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# # 2.DISPLAY TOP FIVE ROWS OF THE DATASETS

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # 3. DISPLAY LAST FIVE ROWS OF THE DATASET

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # 4. FIND THE TOTAL NO. OF ROWS AND COLUMNS PRESENT IN THE DATASET

# %%
data.shape
# Out:
# (1025, 14)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 1025
# Number of Columns 14

# %% [markdown]
# 5. GET INFORMATION ABOUT THE DATA SET (TOTAL NO. OF ROWS,  COLUMNS, DATA TYPE OF EACH COLUMN AND MEMORY REQUIREMENTS)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 6. CHECK NULL VALUES IN THE DATASET

# %%
data.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# here as we can see all the values are 0, which means our dataset is free from null values

# %% [markdown]
# # 7. CHECK FOR DUPLICATE DATA AND DROP THEN FROM THE DATSET

# %%
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# True

# %% [markdown]
# it means our data set contain a duplicate value,so we have to drop it

# %%
data = data.drop_duplicates()

# %%
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# False

# %% [markdown]
# ok,now the duplicated data are drpped

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # 8. GET OVERALL STATISTICS ABOUT THE DATASET

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # 9. DRAW CORRELATION MATRIX

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
plt.figure(figsize=(17,6) )
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(17,6) )
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 10. How many people have heart disease , and how don't have heart disease in the datset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
sns.countplot(x="target",data=data )
plt.xticks ([0,1],['no heart disease','heart disease'])
# Out:
# ([<matplotlib.axis.XTick at 0x7cba830d7b20>,
# ...
#  [Text(0, 0, 'no heart disease'), Text(1, 0, 'heart disease')])

# %% [markdown]
# # 11. Count OF Male And Female In The Dataset

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(x="sex",data=data )
plt.xticks ([0,1],['Female','Male'])
# Out:
# ([<matplotlib.axis.XTick at 0x7cba83257220>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %% [markdown]
# # 12. Find Gender Distribution Acooring To The Target Variable

# %%
sns.countplot(x='sex',hue="target",data=data)
plt.xticks ([0,1],['Female','Male'])
plt.legend(labels=['No disease','Disease'])

# %% [markdown]
# # 13. Age Distribution IN The Dataset

# %%
sns.displot(data['age'] , kde=True ,bins = 10)
plt.show()

# %%
sns.displot(data['trestbps'] , kde=True ,color = 'green')

# %% [markdown]
# # 14. Check Chest Pain Type
#
#    CHEST PAIN TYPE(4 VALUES)
#
#    *   value 0: typical angina
#    *   value 1:atypical angina
#    *   value 2:non-anginal pain
#    *   value 3:asymptomatic

# %%
sns.countplot( x='cp',data=data)
plt.xticks([0,1,2,3],['typical angina','atypical angina','non-anginal pain','asymptomatic'])
# Out:
# ([<matplotlib.axis.XTick at 0x7cba82a72770>,
# ...
#  [Text(0, 0, 'typical angina'),
#   Text(1, 0, 'atypical angina'),
#   Text(2, 0, 'non-anginal pain'),
#   Text(3, 0, 'asymptomatic')])

# %% [markdown]
# # 15. Show The Chest Pain Distribution As per The Target Variable

# %%
sns.countplot(x='cp',hue="target",data=data)
plt.legend(labels=['No disease','Disease'])
plt.show()

# %% [markdown]
# # 16. Fasting Blood Sugar Distribution According to The Target Variable

# %%
sns.countplot(x='fbs',hue="target",data=data)
plt.legend(labels=['No disease','Disease'])
plt.show()

# %% [markdown]
# # 17. Check Resting Blood Pressure Distribution

# %%
data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 18. Compare Resting Blood Pressure As Per Sex Column

# %%
g = sns.FacetGrid(data,hue="sex",aspect=4)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Famale'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# # 19. Show Distribution Of Serum Cholesterol

# %%
data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 20. Pair plot

# %%
sns.pairplot(data)

# %% [markdown]
# # CONCLUSION:
#
#
# We did data visualisation and data analysis of the target variable, age features,and other variables
